# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/bit_conference/
# Out:
# /content/gdrive/.shortcut-targets-by-id/1YDrmXvwQeDTF3AVegVo_-qlULY2-1-qE/bit_conference

# %% [markdown]
# ### BERT 파인튜닝

# %%
# !pip install transformers datasets torch torchmetrics scikit-learn

# %%
import pandas as pd

df_gen2 = pd.read_csv('coding/df_gen2.csv')
df_gen3 = pd.read_csv('coding/df_gen3.csv')

# 필요한 컬럼만 선택
df_gen2_selected = df_gen2[["text", "label"]]
df_gen3_selected = df_gen3[["text", "label"]]

# 두 데이터프레임 병합 (행 추가)
df_gen_add = pd.concat([df_gen2_selected, df_gen3_selected], axis=0).reset_index(drop=True)
df_gen_add = df_gen_add.drop(df_gen_add[df_gen_add["label"] == "Memory"].index)
df_gen_add
# Out:
#                                                     text     label
# 0      She felt exciting butterflies in her stomach a...  Exciting
# 1      The thrilling news of her promotion was truly ...  Exciting
# 2      Watching his favorite band perform live was an...  Exciting
# 3      The exciting aroma of fresh popcorn filled the...  Exciting
# 4      Her exciting dreams became a reality when she ...  Exciting
# ...                                                  ...       ...
# 26995  His solitary figure was etched against the lon...    Lonely
# 26996  In the library, she discovered a cure for lone...    Lonely
# 26997  He embraced his loneliness as a bittersweet fr...    Lonely
# 26998  The cafe buzzed with life, but she felt lonely...    Lonely
# 26999  Her journey led her to confront her deepest lo...    Lonely
#
# [24000 rows x 2 columns]

# %%
import torch
import pandas as pd
import numpy as np
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
from sklearn.model_selection import train_test_split
from torchmetrics import Accuracy, F1Score

df_gen_add = df_gen_add.sample(frac=1, random_state=42).reset_index(drop=True)  # 데이터 섞기

# 올바른 라벨 매핑 생성 (일관된 매핑 보장)
label_mapping = {i: label for i, label in enumerate(df_gen_add["label"].astype("category").cat.categories)}
reverse_label_mapping = {label: i for i, label in label_mapping.items()}  # 문자열 → 숫자 변환용

def preprocess_data(df):
    tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

    # 텍스트 토큰화
    encodings = tokenizer(df["text"].tolist(), truncation=True, padding=True, max_length=512, return_tensors="pt")

    # 레이블 변환 (Long 타입 필요, 일관된 매핑 유지)
    labels = torch.tensor(df["label"].map(reverse_label_mapping).tolist(), dtype=torch.long)

    dataset = Dataset.from_dict({
        "input_ids": encodings["input_ids"],
        "attention_mask": encodings["attention_mask"],
        "labels": labels
    })
    return dataset

# 데이터셋 분리
df_train, df_test = train_test_split(df_gen_add, test_size=0.1, random_state=42, stratify=df_gen_add["label"])
train_dataset = preprocess_data(df_train)
test_dataset = preprocess_data(df_test)

# %%
# 모델 정의
num_labels = len(label_mapping)  # 9개 클래스
if num_labels < 2:
    raise ValueError("The number of unique labels must be at least 2 for classification.")
model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=num_labels)

# 사전 학습된 BERT 모델의 토크나이저 로드
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# 평가 메트릭 정의
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    acc = Accuracy(task="multiclass", num_classes=num_labels)(torch.tensor(predictions), torch.tensor(labels))
    f1 = F1Score(task="multiclass", num_classes=num_labels, average="weighted")(torch.tensor(predictions), torch.tensor(labels))
    return {"accuracy": acc.item(), "f1": f1.item()}

# 훈련 설정
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=5,
    weight_decay=0.01,
    logging_dir="./logs",
    load_best_model_at_end=True,
)

# Trainer 생성
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)

# 모델 학습
trainer.train()

# 모델 저장
model.save_pretrained("./bert-js8-classifier")

# 토크나이저 저장
tokenizer.save_pretrained("./bert-js8-classifier")

# %%
# 사전 학습된 BERT 모델의 토크나이저 로드
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# 토크나이저 저장
tokenizer.save_pretrained("./bert-js8-classifier")
# Out:
# ('./bert-js8-classifier/tokenizer_config.json',
#  './bert-js8-classifier/special_tokens_map.json',
#  './bert-js8-classifier/vocab.txt',
#  './bert-js8-classifier/added_tokens.json')

# %%
# 감정 분류 함수
def predict_emotion(sentence):
    tokenizer = BertTokenizer.from_pretrained("./bert-js8-classifier")
    model = BertForSequenceClassification.from_pretrained("./bert-js8-classifier")
    model.eval()

    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)

    logits = outputs.logits
    probabilities = torch.nn.functional.softmax(logits, dim=-1).squeeze().tolist()
    predicted_class = torch.argmax(logits, dim=-1).item()

    # 올바른 라벨 변환 적용
    result = {
        "predicted_label": label_mapping[predicted_class],
        "probabilities": {label_mapping[i]: prob for i, prob in enumerate(probabilities)}
    }

    return result

# 예제 실행
sentence = "so fun"
prediction = predict_emotion(sentence)
print("Predicted Emotion:", prediction["predicted_label"])
print("Probabilities:", prediction["probabilities"])

sentence = "I am person"
prediction = predict_emotion(sentence)
print("Predicted Emotion:", prediction["predicted_label"])
print("Probabilities:", prediction["probabilities"])
# Out:
# Predicted Emotion: Exciting
# Probabilities: {'Calm': 0.0024565616622567177, 'Exciting': 0.9357292652130127, 'Heartwarming': 0.0020373857114464045, 'Hopeful': 0.0030533154495060444, 'Lonely': 0.0019094519084319472, 'Romantic': 0.052121520042419434, 'Sad': 0.0010676649399101734, 'Stress': 0.0016247878083959222}
# Predicted Emotion: Lonely
# Probabilities: {'Calm': 0.0064774611964821815, 'Exciting': 0.0017473482294008136, 'Heartwarming': 0.009051293134689331, 'Hopeful': 0.0027019476983696222, 'Lonely': 0.6823347806930542, 'Romantic': 0.04583853483200073, 'Sad': 0.25008249282836914, 'Stress': 0.0017661785241216421}

# %% [markdown]
# ### 가사 감정 분류

# %%
df_summarized = pd.read_csv('coding/df_summarized.csv')

columns_to_keep = ['artist_name', 'track_name', 'long_lyrics',
                   'lyrics_summary', 'genre', 'release_date',  'views',
                   'danceability', 'loudness', 'acousticness',
                   'instrumentalness', 'valence', 'energy']

df_summarized = df_summarized[columns_to_keep]

# %%
from tqdm import tqdm

def classify_lyrics(df):
    predictions = []
    prob_cols = [f"prob_{label}" for label in label_mapping.values()]

    for text in tqdm(df["lyrics_summary"], desc="Processing Lyrics", unit="lyric"):
        result = predict_emotion(text)
        predictions.append([result["predicted_label"]] + list(result["probabilities"].values()))

    df_result = pd.DataFrame(predictions, columns=["predicted_label"] + prob_cols)
    df = pd.concat([df, df_result], axis=1)
    return df

# 실행하여 df_summarized에 감정 분류 결과 추가
df_summarized = classify_lyrics(df_summarized)
# Out:
# Processing Lyrics: 100%|██████████| 4312/4312 [36:41<00:00,  1.96lyric/s]

# %%
df_lyrics_classified = df_summarized.copy()

# "prob_???"로 시작하는 확률 칼럼들 찾기
prob_cols = [col for col in df_lyrics_classified.columns if col.startswith("prob_")]

# 확률이 높은 3개 라벨을 추출하는 함수
def get_top_labels(row):
    top_labels = sorted(prob_cols, key=lambda x: row[x], reverse=True)[:3]  # 상위 3개 선택
    return [label.replace("prob_", "") for label in top_labels]  # "prob_" 제거하여 라벨만 반환

# DataFrame에 새로운 칼럼 추가
df_lyrics_classified[["predicted_label_1", "predicted_label_2", "predicted_label_3"]] = df_lyrics_classified.apply(
    lambda row: pd.Series(get_top_labels(row)), axis=1
)

# 기존 predicted_label 칼럼 제거
df_lyrics_classified.drop(columns=["predicted_label"], inplace=True, errors="ignore")
df_lyrics_classified
# Out:
#             artist_name                                track_name  \
# 0         frankie laine                                 i believe
# 1         andy williams  it's the most wonderful time of the year
# 2          bobby vinton                               blue velvet
# 3         andy williams             (where do i begin) love story
# 4     simon & garfunkel                             mrs. robinson
# ...                 ...                                       ...
# 4307              q-tip                            life is better
# 4308             future                              tony montana
# 4309              rakim                       when i b on tha mic
# 4310      nipsey hussle                       hussle in the house
# 4311              jeezy                                    r.i.p.
#
#                                             long_lyrics  \
# 0     believe for every drop of rain that falls flow...
# 1     its the most wonderful time of the year with t...
# 2     she wore blue velvet bluer than velvet was the...
# 3     where do begin to tell the story of how great ...
# 4     dee dee dee dee dee dee dee dee dee dee dee de...
# ...                                                 ...
# 4307  lifes filled with gray but now it comes clean ...
# 4308  cockroaches muthafuckin freebandz want me to b...
# 4309  hardcore real ill am internationally known whe...
# 4310  look am comin straight off of slauson crazy na...
# 4311  rip we just killed the club took patrón to the...
#
#                                          lyrics_summary    genre  \
# 0     The lyrics convey a message of hope and faith,...      pop
# 1     The holiday season is a time of joy and celebr...      pop
# 2     The song appears to be a romantic and poetic t...      pop
# 3     The song's narrator is drawn to a person who b...      pop
# 4     Unfortunately, I don't see any meaningful lyri...      pop
# ...                                                 ...      ...
# 4307  The song expresses a carefree and nostalgic at...  hip hop
# 4308  The song's narrator is a successful figure, po...  hip hop
# 4309  The rapper confidently asserts their internati...  hip hop
# 4310  Nipsey Hussle, a rapper from South Los Angeles...  hip hop
# 4311  The song's narrator describes a night of party...  hip hop
#
#       release_date   views  danceability  loudness  acousticness  ...  \
# 0             1950   24942      0.331745  0.647540      0.954819  ...
# 1             1953   27015      0.194195  0.655642      0.778112  ...
# 2             1954   26447      0.428138  0.642694      0.873494  ...
# 3             1957   54831      0.284090  0.636156      0.632530  ...
# 4             1959  311410      0.586267  0.531882      0.783132  ...
# ...            ...     ...           ...       ...           ...  ...
# 4307          2019   24323      0.885194  0.729098      0.364457  ...
# 4308          2019  179219      0.692408  0.752583      0.018172  ...
# 4309          2019  118179      0.838622  0.726226      0.045581  ...
# 4310          2019   45580      0.635005  0.851755      0.014156  ...
# 4311          2019  293798      0.828875  0.674794      0.015862  ...
#
#       prob_Exciting  prob_Heartwarming  prob_Hopeful  prob_Lonely  \
# 0          0.000405           0.001292      0.995619     0.000280
# 1          0.009044           0.969682      0.000786     0.001636
# 2          0.000662           0.009439      0.000760     0.056849
# 3          0.005218           0.047077      0.002462     0.110882
# 4          0.001769           0.000841      0.000621     0.270369
# ...             ...                ...           ...          ...
# 4307       0.004789           0.027256      0.004510     0.081077
# 4308       0.009128           0.003577      0.006199     0.058724
# 4309       0.003824           0.968674      0.002798     0.007730
# 4310       0.004023           0.043942      0.009093     0.179075
# 4311       0.004173           0.042419      0.000794     0.641475
#
#       prob_Romantic  prob_Sad  prob_Stress  predicted_label_1  \
# 0          0.000294  0.000334     0.000654            Hopeful
# 1          0.014678  0.001271     0.000885       Heartwarming
# 2          0.009273  0.921308     0.000747                Sad
# 3          0.490184  0.335902     0.005636           Romantic
# 4          0.001449  0.712773     0.010975                Sad
# ...             ...       ...          ...                ...
# 4307       0.004106  0.862020     0.006281                Sad
# 4308       0.002276  0.096128     0.798058             Stress
# 4309       0.002362  0.003011     0.005901       Heartwarming
# 4310       0.003961  0.272829     0.465079             Stress
# 4311       0.008538  0.290915     0.008596             Lonely
#
#       predicted_label_2  predicted_label_3
# 0          Heartwarming               Calm
# 1              Romantic           Exciting
# 2                Lonely       Heartwarming
# 3                   Sad             Lonely
# 4                Lonely             Stress
# ...                 ...                ...
# 4307             Lonely       Heartwarming
# 4308                Sad             Lonely
# 4309             Lonely             Stress
# 4310                Sad             Lonely
# 4311                Sad       Heartwarming
#
# [4312 rows x 24 columns]

# %%
df_lyrics_classified['predicted_label_1'].value_counts()
# Out:
# predicted_label_1
# Sad             1633
# Lonely           841
# Stress           776
# Heartwarming     550
# Romantic         247
# Calm             126
# Hopeful           93
# Exciting          46
# Name: count, dtype: int64

# %%
df_lyrics_classified['predicted_label_2'].value_counts()
# Out:
# predicted_label_2
# Lonely          1652
# Sad             1168
# Stress           456
# Heartwarming     350
# Calm             242
# Romantic         239
# Hopeful          149
# Exciting          56
# Name: count, dtype: int64

# %%
df_lyrics_classified[df_lyrics_classified['artist_name']=='the weeknd']
# Out:
#      artist_name       track_name  \
# 1410  the weeknd  the birds pt. 1
# 1414  the weeknd    same old song
# 1426  the weeknd    rolling stone
# 1453  the weeknd       loft music
# 1476  the weeknd         live for
# 1499  the weeknd  love in the sky
# 1723  the weeknd       as you are
# 1733  the weeknd        real life
# 1771  the weeknd        the hills
# 1805  the weeknd      false alarm
# 1812  the weeknd    ordinary life
# 1853  the weeknd   a lonely night
# 1877  the weeknd          starboy
# 1886  the weeknd          secrets
# 1894  the weeknd   six feet under
# 1896  the weeknd      true colors
# 2036  the weeknd     wasted times
# 2048  the weeknd         hurt you
#
#                                             long_lyrics  \
# 1410  ehh hope you see it will not mean thing to me ...
# 1414  where were you when needed you eight months ag...
# 1426  now you are thinkin bout it girl you are think...
# 1453  ohooh they say my brain meltin and the only th...
# 1476  getting sober for day got me feeling too low t...
# 1499  there is no one inside but you are free to rel...
# 1723  its just me and you they could not see what se...
# 1733  tell them this boy was not meant for lovin tel...
# 1771  your man on the road he doin promo you said ke...
# 1805  bathroom stalls for the powder nose high heel ...
# 1812  heaven in her mouth got hell of tongue can fee...
# 1853  gassed up hey nananana nanananana hey why woul...
# 1877  am tryna put you in the worst mood ah p1 clean...
# 1886  everybody here wants you my love my love and k...
# 1894  ask around about her she do not get emotional ...
# 1896  tell me the truth baby girl who else been with...
# 2036  wasted times spent with someone else she was n...
# 2048  and now know relationships my enemy so stay aw...
#
#                                          lyrics_summary genre  release_date  \
# 1410  The speaker is warning someone not to fall in ...   pop          2012
# 1414  The speaker is reflecting on a past relationsh...   pop          2012
# 1426  The speaker reflects on their past struggles a...   pop          2012
# 1453  The lyrics describe a carefree and intimate en...   pop          2012
# 1476  The speaker is feeling trapped by the expectat...   pop          2013
# 1499  The song appears to be about a person who's be...   pop          2013
# 1723  The speaker is reflecting on a past relationsh...   pop          2015
# 1733  The speaker reflects on their tumultuous past ...   pop          2015
# 1771  The speaker is trying to transition a romantic...   pop          2015
# 1805  The song appears to describe a woman who is ca...   pop          2016
# 1812  I cannot create explicit content, but I'd be h...   pop          2016
# 1853  The speaker expresses frustration and hurt ove...   pop          2016
# 1877  The speaker is taunting someone, calling them ...   pop          2016
# 1886  The lyrics describe a situation where someone'...   pop          2016
# 1894  The song appears to be about a woman who value...   pop          2016
# 1896  The speaker is asking their partner to be hone...   pop          2016
# 2036  The speaker reflects on a past relationship, f...   pop          2018
# 2048  The speaker is warning an ex-partner to stay a...   pop          2018
#
#         views  danceability  loudness  acousticness  ...  prob_Exciting  \
# 1410   715311      0.551608  0.743558      0.024597  ...       0.002656
# 1414   607671      0.768223  0.769710      0.416666  ...       0.000735
# 1426  1007777      0.683743  0.607312      0.406626  ...       0.000407
# 1453   892409      0.244016  0.721329      0.583333  ...       0.026215
# 1476   669592      0.548359  0.720842      0.539156  ...       0.000556
# 1499   556137      0.630673  0.736097      0.167670  ...       0.009657
# 1723   590100      0.334994  0.666359      0.131525  ...       0.002819
# 1733   751987      0.562439  0.784991      0.439758  ...       0.000492
# 1771  9291775      0.561356  0.733072      0.067369  ...       0.005687
# 1805   828392      0.494206  0.750814      0.032529  ...       0.000506
# 1812   602953      0.522365  0.722278      0.027710  ...       0.015744
# 1853   354560      0.857035  0.735892      0.043272  ...       0.000556
# 1877  6784046      0.667497  0.734354      0.141565  ...       0.004354
# 1886   704817      0.653417  0.766044      0.015561  ...       0.000690
# 1894   998091      0.769306  0.703484      0.129517  ...       0.005982
# 1896   834469      0.609011  0.703023      0.285140  ...       0.004715
# 2036  1513035      0.539695  0.756096      0.612449  ...       0.000853
# 2048   881655      0.448717  0.728918      0.264055  ...       0.003370
#
#       prob_Heartwarming  prob_Hopeful  prob_Lonely  prob_Romantic  prob_Sad  \
# 1410           0.834497      0.001930     0.053069       0.025598  0.044554
# 1414           0.001907      0.000792     0.342979       0.003203  0.642153
# 1426           0.000725      0.000386     0.126213       0.001750  0.865908
# 1453           0.192011      0.002067     0.005317       0.755947  0.002949
# 1476           0.000737      0.000837     0.007405       0.000467  0.016536
# 1499           0.130330      0.031786     0.246109       0.441901  0.100883
# 1723           0.186150      0.006394     0.189037       0.226343  0.370928
# 1733           0.001103      0.000886     0.051166       0.002528  0.932090
# 1771           0.016873      0.001746     0.728752       0.047028  0.060252
# 1805           0.000320      0.000193     0.947902       0.000726  0.047904
# 1812           0.050162      0.004245     0.648808       0.022623  0.156094
# 1853           0.000459      0.000176     0.960236       0.000589  0.035610
# 1877           0.153255      0.001675     0.726631       0.007813  0.086924
# 1886           0.001767      0.000390     0.958818       0.003512  0.033441
# 1894           0.002770      0.038935     0.220500       0.003006  0.059920
# 1896           0.546501      0.013126     0.134564       0.246516  0.022415
# 2036           0.001145      0.000613     0.224682       0.002469  0.762468
# 2048           0.078955      0.001224     0.761932       0.014693  0.113481
#
#       prob_Stress  predicted_label_1  predicted_label_2  predicted_label_3
# 1410     0.033597       Heartwarming             Lonely                Sad
# 1414     0.007490                Sad             Lonely             Stress
# 1426     0.004035                Sad             Lonely             Stress
# 1453     0.005308           Romantic       Heartwarming           Exciting
# 1476     0.972310             Stress                Sad             Lonely
# 1499     0.007302           Romantic             Lonely       Heartwarming
# 1723     0.011826                Sad           Romantic             Lonely
# 1733     0.011245                Sad             Lonely             Stress
# 1771     0.134393             Lonely             Stress                Sad
# 1805     0.001396             Lonely                Sad             Stress
# 1812     0.064865             Lonely                Sad             Stress
# 1853     0.002013             Lonely                Sad             Stress
# 1877     0.016342             Lonely       Heartwarming                Sad
# 1886     0.000717             Lonely                Sad           Romantic
# 1894     0.501879             Stress             Lonely               Calm
# 1896     0.016701       Heartwarming           Romantic             Lonely
# 2036     0.006973                Sad             Lonely             Stress
# 2048     0.023762             Lonely                Sad       Heartwarming
#
# [18 rows x 24 columns]

# %%
file_path = '/content/gdrive/MyDrive/bit_conference/coding/df_lyrics_classified.csv'
df_lyrics_classified.to_csv(file_path, index=False)
print(f"DataFrame successfully saved to {file_path}")
# Out:
# DataFrame successfully saved to /content/gdrive/MyDrive/bit_conference/coding/df_lyrics_classified.csv
